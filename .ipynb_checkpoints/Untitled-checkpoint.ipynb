# %%
from core import RecurrentNetwork
import matplotlib.pyplot as plt
import matplotlib as mpl

brain = RecurrentNetwork(oscillator_frequency=1000)

for i in range(10):
    print(brain.state[1])
    state = brain.state.numpy()
    brain.step()
    fig, ax = plt.subplots()
    im = ax.imshow(state)
    plt.show()
# Out:
# tensor([0.1470])
# tensor([0.])
# tensor([0.8415])
# tensor([0.9093])
# tensor([0.1411])
# tensor([-0.7568])
# tensor([-0.9589])
# tensor([-0.2794])
# tensor([0.6570])
# tensor([0.9894])
